# %% [markdown]
# # 06 — Experiments, visualization, calibration, and configuration freeze
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Bounded model-width/head/sequence experiments
# - Attention and activation visualizations
# - Representative memory and throughput measurement
# - Thermal/evaluation overhead and safety margin
# - Derive the 24–48-hour corpus/token budget
# - Freeze and hash canonical manifests/configuration
