# %% [markdown]
# # 08 — Evaluation, decoding, attention, and error analysis
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Greedy and beam-search decoding
# - Frozen trivial baselines
# - SacreBLEU signature and chrF evaluation
# - Untouched final-test gate
# - Fixed 20-example meaning/negation/number rubric
# - Attention visualization and categorized failure analysis
# - Hugging Face model card and Gradio readiness evidence
