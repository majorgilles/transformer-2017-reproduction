# %% [markdown]
# # 09 — Complete Transformer and tiny overfit
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#10](https://github.com/majorgilles/transformer-2017-reproduction/issues/10)
# - **Depends on:** `08_decoder.ipynb` / issue #9.

# %%
#| default_exp model

# %% [markdown]
# ## Goal
#
# Assemble approved components into the first complete translator and prove fixture learning.

# %% [markdown]
# ## Required deliverables
#
# - Typed model/config
# - Embedding/output tying
# - Documented initialization
# - Tiny overfit and greedy output

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Paper optimizer schedule, production trainer, WMT data, beam search, and resume.

# %% [markdown]
# ## HITL checkpoint
#
# Approve full topology, tying/init, overfit curve, and fixture translation.
