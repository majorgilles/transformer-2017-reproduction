# %% [markdown]
# # 02 — Shared BPE and vocabulary analysis
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Paper tokenization reference and scaled-corpus deviations
# - Shared English/German BPE training
# - Vocabulary identity and integrity hashes
# - Coverage, frequency, unknowns, and sequence-length analysis
# - Vocabulary-size comparison and freeze criteria
# - Encode/decode round-trip tests
