# %% [markdown]
# # 06 — Feed-forward, residual, dropout, and post-norm
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#7](https://github.com/majorgilles/transformer-2017-reproduction/issues/7)
# - **Depends on:** `05_multi_head_attention.ipynb` / issue #6.

# %%
#| default_exp blocks

# %% [markdown]
# ## Goal
#
# Implement the remaining paper-faithful sublayer mechanics before stack composition.

# %% [markdown]
# ## Required deliverables
#
# - Position-wise ReLU FFN
# - Residual/dropout/post-norm wrapper
# - Order/fidelity tests
# - Activation statistics

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Encoder layer, decoder layer, stacks, and end-to-end model.

# %% [markdown]
# ## HITL checkpoint
#
# Approve ReLU, dropout placement, post-norm order, and fidelity evidence.
