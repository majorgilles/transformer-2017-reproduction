# %% [markdown]
# # 07 — Canonical CLI run preparation and operations
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Preflight validation of environment, config, tokenizer, and manifest
# - Exported CLI command preparation
# - Start, stop, resume, and recovery procedures
# - Metrics, logs, checkpoint health, and retention operations
# - Validation-only checkpoint selection
# - Canonical run record and audit evidence
