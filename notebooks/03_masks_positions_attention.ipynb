# %% [markdown]
# # 03 — Shapes, masks, sinusoidal positions, and explicit attention
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Tensor-shape notation and assertions
# - Padding and causal mask construction/visualization
# - Sinusoidal positional encoding
# - Explicit scaled dot-product attention
# - Multi-head projections, reshape, concatenate, and output projection
# - Numerical, gradient, and masking tests
