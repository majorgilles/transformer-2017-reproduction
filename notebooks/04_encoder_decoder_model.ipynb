# %% [markdown]
# # 04 — Encoder, decoder, complete model, initialization, and tying
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Position-wise feed-forward network
# - Residual, dropout, and layer-normalization order
# - Encoder and decoder layers/stacks
# - Six-plus-six canonical topology
# - Initialization, embedding/output scaling, and weight tying
# - Forward/backward and tiny-batch overfit checks
