# %% [markdown]
# # 00 — Reproduction contract, environment, and diagnostics
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Reproduction goals, fidelity contract, and non-goals
# - Native Windows, uv, PyTorch CUDA, and GPU diagnostics
# - Determinism and exact-resume contract
# - nbdev export and CI expectations
# - Tiny tracer-bullet acceptance gate
