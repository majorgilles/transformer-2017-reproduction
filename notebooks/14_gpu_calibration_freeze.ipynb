# %% [markdown]
# # 14 — GPU/CPU calibration and canonical freeze
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#15](https://github.com/majorgilles/transformer-2017-reproduction/issues/15)
# - **Depends on:** `13_wmt_pipeline.ipynb` / issue #14.

# %%
#| default_exp calibration

# %% [markdown]
# ## Goal
#
# Measure training/deployment constraints and freeze one immutable campaign.

# %% [markdown]
# ## Required deliverables
#
# - 4070 throughput/VRAM report
# - CPU RAM/size/cold-start/latency report
# - Frozen config
# - Hashed campaign manifest

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Canonical run, final test, Hub upload, and public Space.

# %% [markdown]
# ## HITL checkpoint
#
# Approve dimensions, data, budget, margins, and CPU deployment bounds.
