# %% [markdown]
# # 05 — Optimization, batching, checkpointing, and exact resume
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Label smoothing and token-normalized loss
# - Adam and the 2017 warmup schedule
# - Token-based batching and gradient accumulation
# - Mixed precision and finite-gradient handling
# - Atomic checkpoint schema and rolling retention
# - Sampler/cursor state and deterministic process-restart tests
