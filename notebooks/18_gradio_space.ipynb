# %% [markdown]
# # 18 — Bounded Gradio inference experience
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#19](https://github.com/majorgilles/transformer-2017-reproduction/issues/19)
# - **Depends on:** `17_huggingface_package.ipynb` / issue #18.

# %%
#| default_exp space

# %% [markdown]
# ## Goal
#
# Deliver the educational UI using the approved public model or a local fallback.

# %% [markdown]
# ## Required deliverables
#
# - Bounded Gradio UI
# - Cold-start/error behavior
# - Examples/limitations
# - Public URL or fallback record

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Production API, uptime guarantees, corpus access, and silent workarounds.

# %% [markdown]
# ## HITL checkpoint
#
# Approve the public UI or explicit local fallback/publication status.
