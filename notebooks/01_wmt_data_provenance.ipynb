# %% [markdown]
# # 01 — WMT acquisition, provenance, filtering, sharding, and manifests
#
# > Status: empty skeleton.
#
# ## Planned sections
#
# - Source-by-source rights and provenance inventory
# - Pinned acquisition and integrity verification
# - Train/validation/test isolation and leakage checks
# - Deterministic filtering and subset selection
# - Immutable content-hashed raw and processed shards
# - Versioned manifests and reconstruction evidence
