# %% [markdown]
# # 04 — Masks and scaled dot-product attention
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#5](https://github.com/majorgilles/transformer-2017-reproduction/issues/5)
# - **Depends on:** `03_embeddings_positions.ipynb` / issue #4.

# %%
#| default_exp attention

# %% [markdown]
# ## Goal
#
# Implement padding/causal masks and explicit scaled dot-product attention.

# %% [markdown]
# ## Required deliverables
#
# - Padding and causal mask builders
# - Explicit scaled attention
# - Softmax safety tests
# - Attention matrix visualization

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Multi-head projections, blocks, encoder, decoder, and full model.

# %% [markdown]
# ## HITL checkpoint
#
# Approve mask polarity/shapes, numerical safety, equation fidelity, and plots.
