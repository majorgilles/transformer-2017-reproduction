# %% [markdown]
# # 08 — Decoder layer and six-layer stack
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#9](https://github.com/majorgilles/transformer-2017-reproduction/issues/9)
# - **Depends on:** `07_encoder.ipynb` / issue #8.

# %%
#| default_exp decoder

# %% [markdown]
# ## Goal
#
# Compose masked self-attention, cross-attention, and FFN into the decoder stack.

# %% [markdown]
# ## Required deliverables
#
# - Decoder-layer module
# - Six-layer decoder
# - Causality/cross-attention tests
# - Decoder attention plots

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Complete source-target model, output projection, loss, and optimizer.

# %% [markdown]
# ## HITL checkpoint
#
# Approve causality, memory flow, topology, and six-layer evidence.
