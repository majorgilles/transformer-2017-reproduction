# %% [markdown]
# # 13 — Approved WMT processing pipeline
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#14](https://github.com/majorgilles/transformer-2017-reproduction/issues/14)
# - **Depends on:** `12_checkpoint_resume.ipynb` / issue #13.

# %%
#| default_exp wmt

# %% [markdown]
# ## Goal
#
# Acquire approved sources and produce deterministic filtered, sharded, tokenized data.

# %% [markdown]
# ## Required deliverables
#
# - Pinned acquisition records
# - Filtering/dedup/leakage report
# - Hashed shards
# - Candidate data manifest

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# Hardware-derived freeze, canonical training, final evaluation, and publication.

# %% [markdown]
# ## HITL checkpoint
#
# Approve sources, filters, leakage evidence, subsets, and storage.
