# %% [markdown]
# # 13 — WMT pipeline (superseded)
#
# This notebook has no implementation scope. [ADR 0003](../docs/adr/0003-consolidate-wmt-data-pipeline.md) moved all WMT14 acquisition, sharding, manifests, and loading into `01_data_contracts_provenance.ipynb` / issue #2 before shared BPE begins.
#
# Issue [#14](https://github.com/majorgilles/transformer-2017-reproduction/issues/14) is closed as superseded. Later notebooks consume the immutable manifest and exported loader from `transformer_2017_reproduction.data`.
