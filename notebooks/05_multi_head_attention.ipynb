# %% [markdown]
# # 05 — Multi-head self- and cross-attention
#
# > **Status:** empty implementation skeleton.
#
# - **Mapped issue:** [#6](https://github.com/majorgilles/transformer-2017-reproduction/issues/6)
# - **Depends on:** `04_masks_scaled_attention.ipynb` / issue #5.

# %%
#| default_exp multihead

# %% [markdown]
# ## Goal
#
# Compose explicit attention heads with learned projections for self- and cross-attention.

# %% [markdown]
# ## Required deliverables
#
# - Multi-head attention module
# - Self/cross examples
# - Reshape/concatenate tests
# - Per-head visualization

# %% [markdown]
# ## Planned implementation sections
#
# 1. Paper and contract references
# 2. Typed implementation
# 3. Focused tests
# 4. Deterministic visible result
# 5. Exported API and artifact identities

# %% [markdown]
# ## Explicitly deferred
#
# FFN, residual/post-norm, encoder/decoder stacks, and full model.

# %% [markdown]
# ## HITL checkpoint
#
# Approve projection/head semantics, examples, shapes, and gradients.
